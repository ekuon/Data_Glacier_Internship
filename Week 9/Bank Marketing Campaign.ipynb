# %% [markdown]
# # Bank Marketing Campaign Classification

# %%
import warnings 
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from scipy import stats

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Bank Dataset/bank-additional/bank-additional-full.csv', sep = ";")
og_df = df.copy()
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df_test = pd.read_csv('Bank Dataset/bank-additional/bank-additional.csv', sep = ";")
df_test.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
df.shape
# Out:
# (41188, 21)

# %%
df_test.shape
# Out:
# (4119, 21)

# %%
df = (pd.merge(df,df_test, indicator=True, how='outer')
         .query('_merge=="left_only"')
         .drop('_merge', axis=1))
df.shape
# Out:
# (37068, 21)

# %% [markdown]
# ## Checking for any missing values and duplicated values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37068 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             37068 non-null  int64
#  1   job             37068 non-null  object
#  2   marital         37068 non-null  object
#  3   education       37068 non-null  object
#  4   default         37068 non-null  object
#  5   housing         37068 non-null  object
#  6   loan            37068 non-null  object
#  7   contact         37068 non-null  object
#  8   month           37068 non-null  object
#  9   day_of_week     37068 non-null  object
#  10  duration        37068 non-null  int64
#  11  campaign        37068 non-null  int64
#  12  pdays           37068 non-null  int64
#  13  previous        37068 non-null  int64
#  14  poutcome        37068 non-null  object
#  15  emp.var.rate    37068 non-null  float64
#  16  cons.price.idx  37068 non-null  float64
# ...

# %%
df.duplicated().sum()
# Out:
# 11

# %%
df[df.duplicated(keep = False)]
# Out:
#        age          job   marital            education  default housing loan  \
# 1265    39  blue-collar   married             basic.6y       no      no   no
# 1266    39  blue-collar   married             basic.6y       no      no   no
# 12260   36      retired   married              unknown       no      no   no
# 12261   36      retired   married              unknown       no      no   no
# 14155   27   technician    single  professional.course       no      no   no
# 14156   27   technician    single  professional.course       no      no   no
# 16819   47   technician  divorced          high.school       no     yes   no
# 16820   47   technician  divorced          high.school       no     yes   no
# 20072   55     services   married          high.school  unknown      no   no
# 20073   55     services   married          high.school  unknown      no   no
# 20531   41   technician   married  professional.course       no     yes   no
# ...

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (37057, 21)

# %% [markdown]
# **NOTE: After removing the duplicated values, now our dataset is at 37057 observations!**

# %% [markdown]
# ## Checking for any skewness and kurtosis (removing any outliers if present)

# %%
df.skew(axis = 0, skipna = True)
# Out:
# age               0.792042
# duration          3.259341
# campaign          4.822984
# pdays            -4.938570
# previous          3.793975
# emp.var.rate     -0.723683
# cons.price.idx   -0.232451
# cons.conf.idx     0.304577
# euribor3m        -0.708570
# nr.employed      -1.040445
# dtype: float64

# %% [markdown]
# * If the skewness is between -0.5 and 0.5, the data are fairly symmetrical
# * If the skewness is between -1 and -0.5 or between 0.5 and 1, the data are moderately skewed
# * If the skewness is less than -1 or greater than 1, the data are highly skewed

# %%
df.kurt(axis = 0, skipna = True)
# Out:
# age                0.828989
# duration          20.189545
# campaign          37.802262
# pdays             22.391110
# previous          19.633126
# emp.var.rate      -1.064983
# cons.price.idx    -0.830582
# cons.conf.idx     -0.363861
# euribor3m         -1.407974
# nr.employed       -0.012207
# dtype: float64

# %% [markdown]
# * High kurtosis is an indication that there is heavy outliers
# * Low kurtosis is an indication of a lack of outliers

# %%
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  37057.000000  37057.000000  37057.000000  37057.000000  37057.000000
# mean      40.013817    258.485630      2.571282    962.691853      0.171088
# std       10.432631    259.814596      2.791897    186.375961      0.489453
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    319.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  37057.000000    37057.000000   37057.000000  37057.000000  37057.000000
# mean       0.081582       93.575277     -40.503281      3.621287   5167.096357
# ...

# %%
outliers = []
def detect_outliers_iqr(df):
    q1=df.quantile(0.25)
    q3=df.quantile(0.75)
    IQR=q3-q1

    outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]
    return outliers

sample_outliers = detect_outliers_iqr(df[['duration', 'campaign', 'pdays', 'previous']])
print(sample_outliers)
# Out:
#        duration  campaign  pdays  previous
# 0           NaN       NaN    NaN       NaN
# 1           NaN       NaN    NaN       NaN
# 2           NaN       NaN    NaN       NaN
# 3           NaN       NaN    NaN       NaN
# 4           NaN       NaN    NaN       NaN
# ...         ...       ...    ...       ...
# 41182       NaN       NaN    9.0       1.0
# 41183       NaN       NaN    NaN       NaN
# 41185       NaN       NaN    NaN       NaN
# 41186       NaN       NaN    NaN       NaN
# 41187       NaN       NaN    NaN       1.0
#
# [37057 rows x 4 columns]

# %%
sns.boxplot(df[['duration', 'campaign', 'pdays', 'previous']])
plt.title('Boxplot Distribution with Outliers')
plt.show()

# %% [markdown]
# * Due to the large amount of outliers, we decided it would be best to capped the upper limit for the variable duration
#
# * Whereas the outliers for the other variables we will replace them with the median values

# %%
# Capping the Upper Limit
ninetieth_percentile = np.percentile(df['duration'], 90)
df['duration'] = np.where(df['duration'] > ninetieth_percentile, ninetieth_percentile, df['duration'])
df.describe()['duration']
# Out:
# count    37057.000000
# mean       227.063254
# std        160.281976
# min          0.000000
# 25%        102.000000
# 50%        179.000000
# 75%        319.000000
# max        551.000000
# Name: duration, dtype: float64

# %%
# Median Imputation Function 
def impute_outliers_IQR(df):
    q1=df.quantile(0.25)
    q3=df.quantile(0.75)
    IQR=q3-q1
    
    upper = df[~(df>(q3+1.5*IQR))].max()
    lower = df[~(df<(q1-1.5*IQR))].min()
    df = np.where(df > upper, df.median(), np.where(df < lower, df.median(), df))
    
    return df
df['campaign'] = impute_outliers_IQR(df['campaign'])
df['pdays'] = impute_outliers_IQR(df['pdays'])
df['previous'] = impute_outliers_IQR(df['previous'])
df.describe()[['campaign', 'pdays', 'previous']]
# Out:
#            campaign    pdays  previous
# count  37057.000000  37057.0   37057.0
# mean       2.041288    999.0       0.0
# std        1.242712      0.0       0.0
# min        1.000000    999.0       0.0
# 25%        1.000000    999.0       0.0
# 50%        2.000000    999.0       0.0
# 75%        3.000000    999.0       0.0
# max        6.000000    999.0       0.0

# %%
sns.boxplot(df[['duration', 'campaign', 'pdays', 'previous']])
plt.title('Boxplot Distribution Without Outliers')
plt.show()

# %%
df.skew(axis = 0, skipna = True)
# Out:
# age               0.792042
# duration          0.807699
# campaign          1.355049
# pdays             0.000000
# previous          0.000000
# emp.var.rate     -0.723683
# cons.price.idx   -0.232451
# cons.conf.idx     0.304577
# euribor3m        -0.708570
# nr.employed      -1.040445
# dtype: float64

# %%
df.kurt(axis = 0, skipna = True)
# Out:
# age               0.828989
# duration         -0.481956
# campaign          1.359075
# pdays             0.000000
# previous          0.000000
# emp.var.rate     -1.064983
# cons.price.idx   -0.830582
# cons.conf.idx    -0.363861
# euribor3m        -1.407974
# nr.employed      -0.012207
# dtype: float64

# %% [markdown]
# The skewness and kurtosis for each numerical variables is a lot better after handling the outliers compared to what it was before!

# %% [markdown]
# We should note that pdays and previous have 0 skewness and kurtosis. This tells us that theres only one value that is present for both of these variables.

# %% [markdown]
# ## Final Look into the Numerical Variables After Dealing with Outliers

# %%
df.describe()
# Out:
#                 age      duration      campaign    pdays  previous  \
# count  37057.000000  37057.000000  37057.000000  37057.0   37057.0
# mean      40.013817    227.063254      2.041288    999.0       0.0
# std       10.432631    160.281976      1.242712      0.0       0.0
# min       17.000000      0.000000      1.000000    999.0       0.0
# 25%       32.000000    102.000000      1.000000    999.0       0.0
# 50%       38.000000    179.000000      2.000000    999.0       0.0
# 75%       47.000000    319.000000      3.000000    999.0       0.0
# max       98.000000    551.000000      6.000000    999.0       0.0
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  37057.000000    37057.000000   37057.000000  37057.000000  37057.000000
# mean       0.081582       93.575277     -40.503281      3.621287   5167.096357
# std        1.571764        0.578788       4.631606      1.734554     72.092942
# ...

# %% [markdown]
# Taking a closer look into pdays and previous, we can see that the only values for pdays is 999 and the only value for previous is 0. Because only one value is present to the data we can safely drop these.
# * pdays = 999: We will assume that the clients were not previously contacted
# * previous = 0: We will assume that the number of contacts performed before this campaign for this client is 0

# %%
df = df.drop(['pdays', 'previous'], axis=1)
df_test = df_test.drop(['pdays', 'previous'], axis=1)

# %% [markdown]
# ## Looking into the Categorical Variables

# %%
for col in ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 
           'poutcome']:
    print('-', col,'unique values:',df[col].unique())
# Out:
# - job unique values: ['housemaid' 'services' 'admin.' 'blue-collar' 'technician' 'retired'
#  'management' 'unemployed' 'self-employed' 'unknown' 'entrepreneur'
#  'student']
# - marital unique values: ['married' 'single' 'divorced' 'unknown']
# - education unique values: ['basic.4y' 'high.school' 'basic.6y' 'basic.9y' 'professional.course'
#  'unknown' 'university.degree' 'illiterate']
# - default unique values: ['no' 'unknown' 'yes']
# - housing unique values: ['no' 'yes' 'unknown']
# - loan unique values: ['no' 'yes' 'unknown']
# - contact unique values: ['telephone' 'cellular']
# - month unique values: ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'mar' 'apr' 'sep']
# - day_of_week unique values: ['mon' 'tue' 'wed' 'thu' 'fri']
# - poutcome unique values: ['nonexistent' 'failure' 'success']

# %%
df['poutcome'].value_counts()
# Out:
# nonexistent    32028
# failure         3798
# success         1231
# Name: poutcome, dtype: int64

# %% [markdown]
# Here, we will refer 'nonexistent' to be the client not picking up their phone when the calls was made for a previous marketing campaign (poutcome)

# %%
# Drop default as the majority of the classes are no 
df['default'].value_counts()
# Out:
# no         29262
# unknown     7793
# yes            2
# Name: default, dtype: int64

# %%
df_test['default'].value_counts()
# Out:
# no         3315
# unknown     803
# yes           1
# Name: default, dtype: int64

# %%
df = df.replace('unknown', np.nan)
df_test = df_test.replace('unknown', np.nan)
df.isna().sum()
# Out:
# age                  0
# job                291
# marital             69
# education         1563
# default           7793
# housing            885
# loan               885
# contact              0
# month                0
# day_of_week          0
# duration             0
# campaign             0
# poutcome             0
# emp.var.rate         0
# cons.price.idx       0
# cons.conf.idx        0
# euribor3m            0
# nr.employed          0
# y                    0
# dtype: int64

# %%
df = df.drop(columns=['default'])

# Change the NaN for other classes to the most frequent classes 
df['job'] = df['job'].fillna(df['job'].mode().iloc[0])
df['marital'] = df['marital'].fillna(df['marital'].mode().iloc[0])
df['education'] = df['education'].fillna(df['education'].mode().iloc[0])
df['housing'] = df['housing'].fillna(df['housing'].mode().iloc[0])
df['loan'] = df['loan'].fillna(df['loan'].mode().iloc[0])

df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df_test = df_test.drop(columns=['default'])

df_test['job'] = df_test['job'].fillna(df_test['job'].mode().iloc[0])
df_test['marital'] = df_test['marital'].fillna(df_test['marital'].mode().iloc[0])
df_test['education'] = df_test['education'].fillna(df_test['education'].mode().iloc[0])
df_test['housing'] = df_test['housing'].fillna(df_test['housing'].mode().iloc[0])
df_test['loan'] = df_test['loan'].fillna(df_test['loan'].mode().iloc[0])

# %%
# Let's take a look into the categorical variables again 
for col in ['job', 'marital', 'education', 'housing', 'loan', 'contact', 'month', 'day_of_week', 
           'poutcome']:
    print('-', col,'unique values:',df[col].unique())
# Out:
# - job unique values: ['housemaid' 'services' 'admin.' 'blue-collar' 'technician' 'retired'
#  'management' 'unemployed' 'self-employed' 'entrepreneur' 'student']
# - marital unique values: ['married' 'single' 'divorced']
# - education unique values: ['basic.4y' 'high.school' 'basic.6y' 'basic.9y' 'professional.course'
#  'university.degree' 'illiterate']
# - housing unique values: ['no' 'yes']
# - loan unique values: ['no' 'yes']
# - contact unique values: ['telephone' 'cellular']
# - month unique values: ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'mar' 'apr' 'sep']
# - day_of_week unique values: ['mon' 'tue' 'wed' 'thu' 'fri']
# - poutcome unique values: ['nonexistent' 'failure' 'success']

# %%
# Rearranging the categorical values

## since admin. and management is the same we will put these under one category 
lst = [df]
for col in lst: 
    col.loc[col['job'] == 'admin.', 'job'] = 'management'
    
for col in lst: 
    col.loc[col['poutcome'] == 'nonexistent', 'poutcome'] = 'absent'
    
## rearrange the education categorical values 
df['education'] = df['education'].map({'high.school': 'secondary', 'basic.4y': 'bachelor', 'basic.6y': 'master', 
                                       'basic.9y': 'doctorate', 'university.degree': 'bachelor', 
                                      'professional.course': 'certification', 'illiterate': 'primary'})

# %%
# Doing the same for the testing df. 
## Rearranging the categorical values

## since admin. and management is the same we will put these under one category 
lst = [df_test]
for col in lst: 
    col.loc[col['job'] == 'admin.', 'job'] = 'management'
    
for col in lst: 
    col.loc[col['poutcome'] == 'nonexistent', 'poutcome'] = 'absent'
    
## rearrange the education categorical values 
df_test['education'] = df_test['education'].map({'high.school': 'secondary', 'basic.4y': 'bachelor', 'basic.6y': 'master', 
                                       'basic.9y': 'doctorate', 'university.degree': 'bachelor', 
                                      'professional.course': 'certification', 'illiterate': 'primary'})

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Numerical Features Distirbutions 
sns.pairplot(df, hue = 'y', corner = True, palette = 'pastel')

# %%
# Correlation of Numerical Features 
corr = round(df.corr(), 3)
plt.figure(figsize = (10, 8), dpi = 80)
sns.heatmap(corr, cmap = 'coolwarm', annot = True, linewidth = 0.5)
plt.yticks(rotation = 55)
plt.xticks(rotation = 55)
plt.title('Pearson Correlation of Numerical Features')
# Out:
# Text(0.5, 1.0, 'Pearson Correlation of Numerical Features')

# %%
f, ax = plt.subplots(figsize = (8, 4))
colors = ["#FA5858", "#64FE2E"]
labels = "Did NOT Have Personal Loan", "Did Have Personal Loan"

plt.suptitle("% of Condition of Loans", fontsize = 12)

df["loan"].value_counts().plot.pie(explode = [0, 0.10], autopct = "%1.2f%%", colors = colors, 
                                labels = labels, fontsize = 12)
plt.ylabel(" ")
plt.show()

# %%
f, ax = plt.subplots(figsize = (8, 4))
colors = ["#FA5858", "#64FE2E"]
labels = "Did NOT Have Housing Loan", "Did Have Housing Loan"

plt.suptitle("% of Condition of Housing Loan", fontsize = 12)

df["housing"].value_counts().plot.pie(explode = [0, 0.10], autopct = "%1.2f%%", colors = colors, 
                                labels = labels, fontsize = 12)
plt.ylabel(" ")
plt.show()

# %%
import plotly.graph_objs as go
from plotly.offline import iplot

subscribed = df.loc[df['y'] == 'yes']
occupations = df['job'].unique().tolist()

housemaid = subscribed['age'].loc[subscribed['job'] == 'housemaid'].values
services = subscribed['age'].loc[subscribed['job'] == 'services'].values
management = subscribed['age'].loc[subscribed['job'] == 'management'].values
blue_collar = subscribed['age'].loc[subscribed['job'] == 'blue-collar'].values
technician = subscribed['age'].loc[subscribed['job'] == 'technician'].values
retired = subscribed['age'].loc[subscribed['job'] == 'retired'].values
unemployed = subscribed['age'].loc[subscribed['job'] == 'unemployed'].values
self_employed = subscribed['age'].loc[subscribed['job'] == 'self-employed'].values
entrepreneur = subscribed['age'].loc[subscribed['job'] == 'entrepreneur'].values
student = subscribed['age'].loc[subscribed['job'] == 'student'].values

ages = [housemaid, services, management, blue_collar, technician, retired, unemployed, 
        self_employed, entrepreneur, student]
colors = ['rgba(93, 164, 214, 0.5)', 'rgba(255, 144, 14, 0.5)',
          'rgba(44, 160, 101, 0.5)', 'rgba(255, 65, 54, 0.5)', 
          'rgba(207, 114, 255, 0.5)', 'rgba(127, 96, 0, 0.5)',
         'rgba(229, 126, 56, 0.5)', 'rgba(229, 56, 56, 0.5)',
         'rgba(174, 229, 56, 0.5)', 'rgba(229, 56, 56, 0.5)']

traces = []

for xd, yd, cls in zip(occupations, ages, colors):
        traces.append(go.Box(
            y = yd,
            name = xd,
            boxpoints ='all',
            jitter = 0.5,
            whiskerwidth = 0.2,
            marker = dict(size = 2),
            line = dict(width = 1)))

layout = go.Layout(
    title = 'Age Distribution by Occupation ',
    yaxis = dict(
        showgrid = True,
        zeroline = True,
        dtick = 5,
        gridwidth = 1,
        zerolinewidth = 2),
    margin=dict(
        l = 40,
        r = 30,
        b = 80,
        t = 100), showlegend = False)

fig = go.Figure(data=traces, layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="fb6c5f93-fe63-43bc-a144-c746e46948ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb6c5f93-fe63-43bc-a144-c746e46948ae")) {                    Plotly.newPlot(                        "fb6c5f93-fe63-43bc-a144-c746e46948ae",                        [{"boxpoints":"all","jitter":0.5,"line":{"width":1},"marker":{"size":2},"name":"housemaid","whiskerwidth":0.2,"y":[39,45,60,35,46,34,40,50,42,46,33,55,39,45,49,52,31,57,54,42,33,50,29,29,27,54,55,40,45,56,56,47,47,54,59,27,34,38,58,37,53,46,53,53,33,60,46,51,51,63,79,63,63,45,63,37,59,52,65,56,29,53,34,56,49,64,64,64,62,38,66,65,60,82,58,80,85,85,85,57,57,53,76,76,60,83,66,48,50,48,50,67,37,37,37],"type":"box"},{"boxpoints":"all","jitter":0.5,"line":{"width":1},"m
# ...

# %%
sns.countplot(x = 'marital', hue = 'y', data = df, palette = ["crimson", "springgreen"])
plt.legend(title='Deposit', loc='upper right')
plt.xlabel("Marital Status")
plt.title("Marital Status Based on if Client Subscribed or Not")
plt.show()
